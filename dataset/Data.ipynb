# %%
import pandas as pd

df = pd.read_csv("tested.csv", encoding="utf-8", sep=",", on_bad_lines="skip")
df.head(420)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
print("<-------Data inspection------>")
print("_"*30)
print("Data infomation:\n")
df.info()
print("Data description:\n",df.describe(),"\n")
print("Data if null exists:\n")
df.isnull()
# Out:
# <-------Data inspection------>
# ______________________________
# Data infomation:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB
# Data description:
#         PassengerId    Survived      Pclass         Age       SibSp  \
# ...

# %%
print("<----Data selection---->")
print("_"*30)

df_selected = df[["Survived", "Name", "Sex", "Age", "PassengerId", "Cabin"]]
df_selected.head(420)
# Out:
# <----Data selection---->
# ______________________________
#      Survived                                          Name     Sex   Age  \
# 0           0                              Kelly, Mr. James    male  34.5
# 1           1              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2           0                     Myles, Mr. Thomas Francis    male  62.0
# 3           0                              Wirz, Mr. Albert    male  27.0
# 4           1  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..        ...                                           ...     ...   ...
# 413         0                            Spector, Mr. Woolf    male   NaN
# 414         1                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415         0                  Saether, Mr. Simon Sivertsen    male  38.5
# 416         0                           Ware, Mr. Frederick    male   NaN
# 417         0                      Peter, Master. Michael J    male   NaN
#
# ...

# %%
print("Data Flitering")

df_surviors = df[df['Survived'] == 1]
df_surviors.head(420)
# Out:
# Data Flitering
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ...

# %%
df_dead = df[df['Survived'] == 0]
df_dead.head(420)
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0            892         0       3              Kelly, Mr. James  male  34.5
# 2            894         0       2     Myles, Mr. Thomas Francis  male  62.0
# 3            895         0       3              Wirz, Mr. Albert  male  27.0
# 5            897         0       3    Svensson, Mr. Johan Cervin  male  14.0
# 7            899         0       2  Caldwell, Mr. Albert Francis  male  26.0
# ..           ...       ...     ...                           ...   ...   ...
# 407         1299         0       1    Widener, Mr. George Dunton  male  50.0
# 413         1305         0       3            Spector, Mr. Woolf  male   NaN
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
# 417         1309         0       3      Peter, Master. Michael J  male   NaN
#
# ...

# %%
data = pd.read_csv("tested.csv")
bool_series = pd.isnull(data["Age"])
missing_age_data = data[bool_series]
missing_age_data
# Out:
#      PassengerId  Survived  Pclass  \
# 10           902         0       3
# 22           914         1       1
# 29           921         0       3
# 33           925         1       3
# 36           928         1       3
# ..           ...       ...     ...
# 408         1300         1       3
# 410         1302         1       3
# 413         1305         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 10                                    Ilieff, Mr. Ylio    male  NaN      0
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female  NaN      0
# 29                                   Samaan, Mr. Elias    male  NaN      2
# 33   Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"  female  NaN      1
# 36                                 Roth, Miss. Sarah A  female  NaN      0
# ..                                                 ...     ...  ...    ...
# ...
